# %% [markdown]
# __Custom exception__(__Raise and throw an exception__)

# %%
class Error(Exception):
    pass

class dobException(Error):
    pass

# %%
year=int(("Enter the dob"))
age=2024-year


try:

   if age<=30 and age>=20:
       print("The age is valid so you can apply for the exam")
   else:
      raise dobException
except dobException:
    print("Sorry, your age showuld be grated than 20 or less thean 20")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 year=int(("Enter the dob"))
#       2 age=2024-year
#       5 try:
#
# ValueError: invalid literal for int() with base 10: 'Enter the dob'
