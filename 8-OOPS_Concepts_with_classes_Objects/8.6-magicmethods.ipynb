# %% [markdown]
# `Magic Methods`
#
# Magic methods in python, also known as dunder methods (double underscore methods), are special methods that start and end with double underscore. These methods enable you to define the behaviour of objects for built-in operations, such as arithmetic operations, comparisons and more
#
# Magic methods are predefined methods in python that can override to change the behaviour of your objects. Some common magic methods include:

# %%
'''
__init__: Initializes a new instance of a class
__str__: Returns a string representation of an object.
__repr__: Returns an official string representation of an object.
__len__: Returns the length of an object
__getitem__: Gets an item from a container
__setitem__: sets an item in a container
'''
