# %% [markdown]
# __Multi threading And Multi processing__

# %% [markdown]
# Program
#
# A program is a sequence of instructions written in programming languages
#
# eg: python, c++

# %% [markdown]
# Process
#
# A process is simply an instance of a program that is being executed
#
# eg: browser, excel
#
# seperate memory space: one process cannot corrupt another process
#
# I/O Requirements

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# __Thread__
#
# A thread is a unit of execution within a process
#
# ![image.png](attachment:image.png)
