# %% [markdown]
# Decorators
#
# Decorators are a powerful and flexible feature in python that allows you to modify the behaviour fo a function or class method. They are commonly used to add functionality to functions or methods without modifying their actual code. This lesson covers the basics of decorator, including how to create adn use them.

# %%
## function copy
## closures
## decorators

# %%
## function copy
def welcome():
    return "Welcome to the advanced python course"

welcome()
# Out:
# 'Welcome to the advanced python course'

# %%
wel=welcome
print(wel())
del welcome
print(wel())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 wel=welcome
#       2 print(wel())
#       3 del welcome
#
# NameError: name 'welcome' is not defined

# %%
## closures

def main_welcome():
    msg="welcome"
    def sub_welcome_method():
        print("welcome to the advancd python course")

        print("please learn these concepts properly")
    return sub_welcome_method()

# %%
main_welcome()
# Out:
# welcome to the advancd python course
# please learn these concepts properly

# %%
def main_welcome(func):

    def sub_welcome_method():
        print("Welcome to the advance python course")
        print(func())
        print("please learn these concepts properly")
    return sub_Welcome_method()

# %%
main_Welcome(len([1,2,3,4,5,6]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 main_Welcome(len([1,2,3,4,5,6]))
#
# NameError: name 'main_Welcome' is not defined

# %%
## Decorator

def main_welcome(func):

    def sub_welcome_method():
        print("Welcome to the advance python course")
        func()
        print("please learn these concepts properly")
    return sub_Welcome_method()

# %%
def course_introduction():
    print("This is an advanced python course")

course_introduction()
# Out:
# This is an advanced python course

# %%
main_welcome(course_intorudction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 main_welcome(course_intorudction)
#
# NameError: name 'course_intorudction' is not defined
