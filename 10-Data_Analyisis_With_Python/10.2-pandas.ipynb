# %% [markdown]
# __Pandas-DataFrame And Series__
#
# Pandas is a powerful data manipulation library in python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and DataFrame. A series is a one-dimensional array-like object, while a Dataframe is a two dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns)

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
## Series
## pandas series is a one-dimensional array-like object that can hold any data type. It is similar to column in a table

import pandas as pd
data=[1,2,3,4,5]
series=pd.Series(data)
print("Series \n", series)
print(type(series))
# Out:
# Series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
### create as series from dictionary

data={'a':1, 'b':2, 'c':3}
series_dict = pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data=[10,20,30]
index=['a','b','c']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
## Data frame
## create a Dataframe from a dictionary of list

data={
    'Name':['Krish', 'John', 'Jack'],
    'Age': [25,30,45],
    'City':['Bangalore', 'New york', 'Florida']
}
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New york
# 2   Jack   45    Florida
# <class 'pandas.core.frame.DataFrame'>

# %%
import numpy as np
np.array(df)
# Out:
# array([['Krish', 25, 'Bangalore'],
#        ['John', 30, 'New york'],
#        ['Jack', 45, 'Florida']], dtype=object)

# %%
## Create a Data frame from a list of Dictionaries

data=[
    {'Name': 'Krish', 'Age':32, 'City':'Bangalore'},
    {'Name': 'jphn', 'Age':32, 'City':'florida'},
    {'Name': 'kelly', 'Age':52, 'City':'minnesota'},

]
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  Age       City
# 0  Krish   32  Bangalore
# 1   jphn   32    florida
# 2  kelly   52  minnesota
# <class 'pandas.core.frame.DataFrame'>

# %%
df=pd.read_csv('online_sales_data.csv')
df.head(5)
# Out:
#   Transaction ID        Date Product Category           Product Name  \
# 0          T1001  2025-09-15      Electronics       Wireless Earbuds
# 1          T1002  2025-09-16   Home & Kitchen        Electric Kettle
# 2          T1003  2025-09-17         Clothing          Men's T-Shirt
# 3          T1004  2025-09-18            Books  Data Science Handbook
# 4          T1005  2025-09-19           Beauty     Moisturizing Cream
#
#    Units Sold  Unit Price  Total Revenue   Region  Payment Method
# 0           3       49.99         149.97    North     Credit Card
# 1           5       25.50         127.50     West             UPI
# 2          10       12.99         129.90    South            Cash
# 3           2       45.00          90.00     East      Debit Card
# 4           4       18.75          75.00  Central  Digital Wallet

# %%
### Accessing DATA FROM DATAFRAME

df
# Out:
#   Transaction ID        Date Product Category           Product Name  \
# 0          T1001  2025-09-15      Electronics       Wireless Earbuds
# 1          T1002  2025-09-16   Home & Kitchen        Electric Kettle
# 2          T1003  2025-09-17         Clothing          Men's T-Shirt
# 3          T1004  2025-09-18            Books  Data Science Handbook
# 4          T1005  2025-09-19           Beauty     Moisturizing Cream
#
#    Units Sold  Unit Price  Total Revenue   Region  Payment Method
# 0           3       49.99         149.97    North     Credit Card
# 1           5       25.50         127.50     West             UPI
# 2          10       12.99         129.90    South            Cash
# 3           2       45.00          90.00     East      Debit Card
# 4           4       18.75          75.00  Central  Digital Wallet

# %%
df['Date']
# Out:
# 0    2025-09-15
# 1    2025-09-16
# 2    2025-09-17
# 3    2025-09-18
# 4    2025-09-19
# Name: Date, dtype: object

# %%
df.iloc[0]
# Out:
# Transaction ID                 T1001
# Date                      2025-09-15
# Product Category         Electronics
# Product Name        Wireless Earbuds
# Units Sold                         3
# Unit Price                     49.99
# Total Revenue                 149.97
# Region                         North
# Payment Method           Credit Card
# Name: 0, dtype: object

# %%
type(df(Date))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 type(df(Date))
#
# NameError: name 'Date' is not defined

# %%
df.iloc[0][2]
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16156\2519637664.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][2]
# 'Electronics'

# %%
## Accessing a specified element

df['Date']
# Out:
# 0    2025-09-15
# 1    2025-09-16
# 2    2025-09-17
# 3    2025-09-18
# 4    2025-09-19
# Name: Date, dtype: object

# %%
df.at[1,'Region']
# Out:
# 'West'

# %%
df
# Out:
#   Transaction ID        Date Product Category           Product Name  \
# 0          T1001  2025-09-15      Electronics       Wireless Earbuds
# 1          T1002  2025-09-16   Home & Kitchen        Electric Kettle
# 2          T1003  2025-09-17         Clothing          Men's T-Shirt
# 3          T1004  2025-09-18            Books  Data Science Handbook
# 4          T1005  2025-09-19           Beauty     Moisturizing Cream
#
#    Units Sold  Unit Price  Total Revenue   Region  Payment Method
# 0           3       49.99         149.97    North     Credit Card
# 1           5       25.50         127.50     West             UPI
# 2          10       12.99         129.90    South            Cash
# 3           2       45.00          90.00     East      Debit Card
# 4           4       18.75          75.00  Central  Digital Wallet

# %%
df.at[2,'Product Name']
# Out:
# "Men's T-Shirt"

# %%
## accessing a specified element using iat
df.iat[3,3]
# Out:
# 'Data Science Handbook'

# %%
## Data manipulation with dataframe
df
# Out:
#   Transaction ID        Date Product Category           Product Name  \
# 0          T1001  2025-09-15      Electronics       Wireless Earbuds
# 1          T1002  2025-09-16   Home & Kitchen        Electric Kettle
# 2          T1003  2025-09-17         Clothing          Men's T-Shirt
# 3          T1004  2025-09-18            Books  Data Science Handbook
# 4          T1005  2025-09-19           Beauty     Moisturizing Cream
#
#    Units Sold  Unit Price  Total Revenue   Region  Payment Method
# 0           3       49.99         149.97    North     Credit Card
# 1           5       25.50         127.50     West             UPI
# 2          10       12.99         129.90    South            Cash
# 3           2       45.00          90.00     East      Debit Card
# 4           4       18.75          75.00  Central  Digital Wallet

# %%
df['Ecommerce Platform']=['Amazon', 'Flipkart', 'Blinkit', 'Instamart', 'Zepto']

# %%
df
# Out:
#   Transaction ID        Date Product Category           Product Name  \
# 0          T1001  2025-09-15      Electronics       Wireless Earbuds
# 1          T1002  2025-09-16   Home & Kitchen        Electric Kettle
# 2          T1003  2025-09-17         Clothing          Men's T-Shirt
# 3          T1004  2025-09-18            Books  Data Science Handbook
# 4          T1005  2025-09-19           Beauty     Moisturizing Cream
#
#    Units Sold  Unit Price  Total Revenue   Region  Payment Method  \
# 0           3       49.99         149.97    North     Credit Card
# 1           5       25.50         127.50     West             UPI
# 2          10       12.99         129.90    South            Cash
# 3           2       45.00          90.00     East      Debit Card
# 4           4       18.75          75.00  Central  Digital Wallet
#
#   Ecommerce Platform
# 0             Amazon
# 1           Flipkart
# 2            Blinkit
# 3          Instamart
# 4              Zepto

# %%
## Remove a column
df.drop('Region',axis=7)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\ASUS\Downloads\python\venv\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 7
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16156\1861362883.py in ?()
#       1 ## Remove a column
# ----> 2 df.drop('Region',axis=7)
#
# c:\Users\ASUS\Downloads\python\venv\Lib\site-packages\pandas\core\frame.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5584                 weight  250.0   150.0
#    5585         falcon  speed   320.0   250.0
# ...

# %%
df
# Out:
#   Transaction ID        Date Product Category           Product Name  \
# 0          T1001  2025-09-15      Electronics       Wireless Earbuds
# 1          T1002  2025-09-16   Home & Kitchen        Electric Kettle
# 2          T1003  2025-09-17         Clothing          Men's T-Shirt
# 3          T1004  2025-09-18            Books  Data Science Handbook
# 4          T1005  2025-09-19           Beauty     Moisturizing Cream
#
#    Units Sold  Unit Price  Total Revenue   Region  Payment Method  \
# 0           3       49.99         149.97    North     Credit Card
# 1           5       25.50         127.50     West             UPI
# 2          10       12.99         129.90    South            Cash
# 3           2       45.00          90.00     East      Debit Card
# 4           4       18.75          75.00  Central  Digital Wallet
#
#   Ecommerce Platform
# 0             Amazon
# 1           Flipkart
# 2            Blinkit
# 3          Instamart
# 4              Zepto

# %%
#Remove a column
df.drop('Region',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 2
#       1 #Remove a column
# ----> 2 df.drop('Region',axis=1,inplace=True)
#
# File c:\Users\ASUS\Downloads\python\venv\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
# ...

# %%
df
# Out:
#   Transaction ID        Date Product Category           Product Name  \
# 0          T1001  2025-09-15      Electronics       Wireless Earbuds
# 1          T1002  2025-09-16   Home & Kitchen        Electric Kettle
# 2          T1003  2025-09-17         Clothing          Men's T-Shirt
# 3          T1004  2025-09-18            Books  Data Science Handbook
# 4          T1005  2025-09-19           Beauty     Moisturizing Cream
#
#    Units Sold  Unit Price  Total Revenue  Payment Method Ecommerce Platform
# 0           3       49.99         149.97     Credit Card             Amazon
# 1           5       25.50         127.50             UPI           Flipkart
# 2          10       12.99         129.90            Cash            Blinkit
# 3           2       45.00          90.00      Debit Card          Instamart
# 4           4       18.75          75.00  Digital Wallet              Zepto

# %%
df
# Out:
#   Transaction ID        Date Product Category           Product Name  \
# 0          T1001  2025-09-15      Electronics       Wireless Earbuds
# 1          T1002  2025-09-16   Home & Kitchen        Electric Kettle
# 2          T1003  2025-09-17         Clothing          Men's T-Shirt
# 3          T1004  2025-09-18            Books  Data Science Handbook
# 4          T1005  2025-09-19           Beauty     Moisturizing Cream
#
#    Units Sold  Unit Price  Total Revenue  Payment Method Ecommerce Platform
# 0           3       49.99         149.97     Credit Card             Amazon
# 1           5       25.50         127.50             UPI           Flipkart
# 2          10       12.99         129.90            Cash            Blinkit
# 3           2       45.00          90.00      Debit Card          Instamart
# 4           4       18.75          75.00  Digital Wallet              Zepto

# %%
## Add increment to the column
df['Total Revenue']=df['Total Revenue']+1

# %%
df
# Out:
#   Transaction ID        Date Product Category           Product Name  \
# 0          T1001  2025-09-15      Electronics       Wireless Earbuds
# 1          T1002  2025-09-16   Home & Kitchen        Electric Kettle
# 2          T1003  2025-09-17         Clothing          Men's T-Shirt
# 3          T1004  2025-09-18            Books  Data Science Handbook
# 4          T1005  2025-09-19           Beauty     Moisturizing Cream
#
#    Units Sold  Unit Price  Total Revenue  Payment Method Ecommerce Platform
# 0           3       49.99         150.97     Credit Card             Amazon
# 1           5       25.50         128.50             UPI           Flipkart
# 2          10       12.99         130.90            Cash            Blinkit
# 3           2       45.00          91.00      Debit Card          Instamart
# 4           4       18.75          76.00  Digital Wallet              Zepto

# %%
df.drop(0)
# Out:
#   Transaction ID        Date Product Category           Product Name  \
# 1          T1002  2025-09-16   Home & Kitchen        Electric Kettle
# 2          T1003  2025-09-17         Clothing          Men's T-Shirt
# 3          T1004  2025-09-18            Books  Data Science Handbook
# 4          T1005  2025-09-19           Beauty     Moisturizing Cream
#
#    Units Sold  Unit Price  Total Revenue  Payment Method Ecommerce Platform
# 1           5       25.50          128.5             UPI           Flipkart
# 2          10       12.99          130.9            Cash            Blinkit
# 3           2       45.00           91.0      Debit Card          Instamart
# 4           4       18.75           76.0  Digital Wallet              Zepto

# %%
df
# Out:
#   Transaction ID        Date Product Category           Product Name  \
# 0          T1001  2025-09-15      Electronics       Wireless Earbuds
# 1          T1002  2025-09-16   Home & Kitchen        Electric Kettle
# 2          T1003  2025-09-17         Clothing          Men's T-Shirt
# 3          T1004  2025-09-18            Books  Data Science Handbook
# 4          T1005  2025-09-19           Beauty     Moisturizing Cream
#
#    Units Sold  Unit Price  Total Revenue  Payment Method Ecommerce Platform
# 0           3       49.99         150.97     Credit Card             Amazon
# 1           5       25.50         128.50             UPI           Flipkart
# 2          10       12.99         130.90            Cash            Blinkit
# 3           2       45.00          91.00      Debit Card          Instamart
# 4           4       18.75          76.00  Digital Wallet              Zepto

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#   Transaction ID        Date Product Category           Product Name  \
# 1          T1002  2025-09-16   Home & Kitchen        Electric Kettle
# 2          T1003  2025-09-17         Clothing          Men's T-Shirt
# 3          T1004  2025-09-18            Books  Data Science Handbook
# 4          T1005  2025-09-19           Beauty     Moisturizing Cream
#
#    Units Sold  Unit Price  Total Revenue  Payment Method Ecommerce Platform
# 1           5       25.50          128.5             UPI           Flipkart
# 2          10       12.99          130.9            Cash            Blinkit
# 3           2       45.00           91.0      Debit Card          Instamart
# 4           4       18.75           76.0  Digital Wallet              Zepto

# %%
df=pd.read_csv('online_sales_data.csv')
df.head(5)
# Out:
#   Transaction ID        Date Product Category           Product Name  \
# 0          T1001  2025-09-15      Electronics       Wireless Earbuds
# 1          T1002  2025-09-16   Home & Kitchen        Electric Kettle
# 2          T1003  2025-09-17         Clothing          Men's T-Shirt
# 3          T1004  2025-09-18            Books  Data Science Handbook
# 4          T1005  2025-09-19           Beauty     Moisturizing Cream
#
#    Units Sold  Unit Price  Total Revenue   Region  Payment Method
# 0           3       49.99         149.97    North     Credit Card
# 1           5       25.50         127.50     West             UPI
# 2          10       12.99         129.90    South            Cash
# 3           2       45.00          90.00     East      Debit Card
# 4           4       18.75          75.00  Central  Digital Wallet

# %%
# Display the data types of each column
print("Data types:\n", df.dtypes)

# Describe the dataframe
print("Satistical summary:\n", df.describe())

#Group by a column and perform an aggregation
grouped = df.groupby('Category')['Value'].mean()
print("Mean value by category:\n", grouped)
# Out:
# Data types:
#  Transaction ID       object
# Date                 object
# Product Category     object
# Product Name         object
# Units Sold            int64
# Unit Price          float64
# Total Revenue       float64
# Region               object
# Payment Method       object
# dtype: object
# Satistical summary:
#         Units Sold  Unit Price  Total Revenue
# count    5.000000    5.000000       5.000000
# mean     4.800000   30.446000     114.474000
# std      3.114482   16.276963      30.922393
# min      2.000000   12.990000      75.000000
# 25%      3.000000   18.750000      90.000000
# 50%      4.000000   25.500000     127.500000
# 75%      5.000000   45.000000     129.900000
# max     10.000000   49.990000     149.970000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 8
#       5 print("Satistical summary:\n", df.describe())
# ...

# %%
df.describe()
# Out:
#        Units Sold  Unit Price  Total Revenue
# count    5.000000    5.000000       5.000000
# mean     4.800000   30.446000     114.474000
# std      3.114482   16.276963      30.922393
# min      2.000000   12.990000      75.000000
# 25%      3.000000   18.750000      90.000000
# 50%      4.000000   25.500000     127.500000
# 75%      5.000000   45.000000     129.900000
# max     10.000000   49.990000     149.970000
